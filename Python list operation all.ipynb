# %%
#https://www.tutorialspoint.com/python/python_lists.htm

#List element operation in python:

# List method
my_list = [1, 2, 3, 3, 4]
print(my_list)
my_list.append(5)
print(my_list)
#[1, 2, 3, 3, 4, 5]
# Out:
# [1, 2, 3, 3, 4]
# [1, 2, 3, 3, 4, 5]
